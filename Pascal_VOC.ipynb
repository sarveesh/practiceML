# %% [markdown]
# <a href="https://colab.research.google.com/github/sarveesh/practiceML/blob/main/Pascal_VOC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls -la /content/drive/MyDrive/Darknet/
# Out:
# total 0

# %%
# !sudo apt-get install tree
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 40 not upgraded.
# Need to get 40.7 kB of archives.
# After this operation, 105 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tree amd64 1.7.0-5 [40.7 kB]
# Fetched 40.7 kB in 1s (70.4 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tree.
# ...

# %%
# !tree /content/drive/MyDrive/Darknet
# Out:
# /content/drive/MyDrive/Darknet
#
# 0 directories, 0 files

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
# !nvidia-smi
# Out:
# Wed Aug  4 11:25:28 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
#!tar -xzvf “/content/drive/My Drive/Darknet/cudnn-10.1-linux-x64-v7.6.5.32.tgz” -C /usr/local/
# !chmod +x /usr/local/cuda-11.0/include/cudnn.h
# !cat /usr/local/cuda-11.0/include/cudnn.h | grep CUDNN_MAJOR -A 2
# Out:
# chmod: cannot access '/usr/local/cuda-11.0/include/cudnn.h': No such file or directory
# cat: /usr/local/cuda-11.0/include/cudnn.h: No such file or directory

# %%
# !nvidia-smi
# Out:
# Wed Aug  4 07:05:34 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
ls
# Out:
# darknet/  drive/  sample_data/

# %%
# !git clone https://github.com/pjreddie/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 5937, done.
# remote: Total 5937 (delta 0), reused 0 (delta 0), pack-reused 5937
# Receiving objects: 100% (5937/5937), 6.35 MiB | 28.89 MiB/s, done.
# Resolving deltas: 100% (3925/3925), done.

# %%
cd darknet/
# Out:
# /content/darknet

# %%
# !make
# Out:
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/gemm.c -o obj/gemm.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/cuda.c -o obj/cuda.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/deconvolutional_layer.c -o obj/deconvolutional_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/list.c -o obj/list.o
# ...

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2021-08-04 07:10:03--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M   101MB/s    in 2.3s
#
# 2021-08-04 07:10:05 (101 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/dog.jpg
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32  0.639 BFLOPs
#     1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32  0.379 BFLOPs
#     3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     4 res    1                 304 x 304 x  64   ->   304 x 304 x  64
#     5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#     7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     8 res    5                 152 x 152 x 128   ->   152 x 152 x 128
#     9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#    10 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
# ...

# %%
# !wget https://pjreddie.com/media/files/yolov3-tiny.weights
# Out:
# --2021-08-04 07:10:22--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘yolov3-tiny.weights’
#
# yolov3-tiny.weights 100%[===================>]  33.79M  92.5MB/s    in 0.4s
#
# 2021-08-04 07:10:23 (92.5 MB/s) - ‘yolov3-tiny.weights’ saved [35434956/35434956]

# %%
# !./darknet detect cfg/yolov3-tiny.cfg yolov3-tiny.weights data/dog.jpg
# Out:
# layer     filters    size              input                output
#     0 conv     16  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  16  0.150 BFLOPs
#     1 max          2 x 2 / 2   416 x 416 x  16   ->   208 x 208 x  16
#     2 conv     32  3 x 3 / 1   208 x 208 x  16   ->   208 x 208 x  32  0.399 BFLOPs
#     3 max          2 x 2 / 2   208 x 208 x  32   ->   104 x 104 x  32
#     4 conv     64  3 x 3 / 1   104 x 104 x  32   ->   104 x 104 x  64  0.399 BFLOPs
#     5 max          2 x 2 / 2   104 x 104 x  64   ->    52 x  52 x  64
#     6 conv    128  3 x 3 / 1    52 x  52 x  64   ->    52 x  52 x 128  0.399 BFLOPs
#     7 max          2 x 2 / 2    52 x  52 x 128   ->    26 x  26 x 128
#     8 conv    256  3 x 3 / 1    26 x  26 x 128   ->    26 x  26 x 256  0.399 BFLOPs
#     9 max          2 x 2 / 2    26 x  26 x 256   ->    13 x  13 x 256
#    10 conv    512  3 x 3 / 1    13 x  13 x 256   ->    13 x  13 x 512  0.399 BFLOPs
# ...

# %%
# !wget https://pjreddie.com/media/files/VOCtrainval_11-May-2012.tar
# Out:
# --2021-08-04 07:10:43--  https://pjreddie.com/media/files/VOCtrainval_11-May-2012.tar
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1999639040 (1.9G) [application/octet-stream]
# Saving to: ‘VOCtrainval_11-May-2012.tar’
#
# VOCtrainval_11-May- 100%[===================>]   1.86G  99.7MB/s    in 19s
#
# 2021-08-04 07:11:02 (99.9 MB/s) - ‘VOCtrainval_11-May-2012.tar’ saved [1999639040/1999639040]

# %%
# !wget https://pjreddie.com/media/files/VOCtrainval_06-Nov-2007.tar
# Out:
# --2021-08-04 07:11:02--  https://pjreddie.com/media/files/VOCtrainval_06-Nov-2007.tar
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 460032000 (439M) [application/octet-stream]
# Saving to: ‘VOCtrainval_06-Nov-2007.tar’
#
# VOCtrainval_06-Nov- 100%[===================>] 438.72M  41.5MB/s    in 11s
#
# 2021-08-04 07:11:13 (41.1 MB/s) - ‘VOCtrainval_06-Nov-2007.tar’ saved [460032000/460032000]

# %%
# !wget https://pjreddie.com/media/files/VOCtest_06-Nov-2007.tar
# Out:
# --2021-08-04 07:11:13--  https://pjreddie.com/media/files/VOCtest_06-Nov-2007.tar
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 451020800 (430M) [application/octet-stream]
# Saving to: ‘VOCtest_06-Nov-2007.tar’
#
# VOCtest_06-Nov-2007 100%[===================>] 430.13M  30.1MB/s    in 13s
#
# 2021-08-04 07:11:26 (32.9 MB/s) - ‘VOCtest_06-Nov-2007.tar’ saved [451020800/451020800]

# %%
# !tar xf VOCtrainval_11-May-2012.tar

# %%
# !tar xf VOCtrainval_06-Nov-2007.tar

# %%
# !tar xf VOCtest_06-Nov-2007.tar

# %%
# !wget https://pjreddie.com/media/files/voc_label.py
# Out:
# --2021-08-04 07:12:41--  https://pjreddie.com/media/files/voc_label.py
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2042 (2.0K) [application/octet-stream]
# Saving to: ‘voc_label.py’
#
# voc_label.py        100%[===================>]   1.99K  --.-KB/s    in 0s
#
# 2021-08-04 07:12:41 (377 MB/s) - ‘voc_label.py’ saved [2042/2042]

# %%
# !python voc_label.py

# %%
ls
# Out:
# 2007_test.txt   examples/       LICENSE.mit      src/
# 2007_train.txt  include/        LICENSE.v1       VOCdevkit/
# 2007_val.txt    libdarknet.a    Makefile         voc_label.py
# 2012_train.txt  libdarknet.so*  obj/             VOCtest_06-Nov-2007.tar
# 2012_val.txt    LICENSE         predictions.jpg  VOCtrainval_06-Nov-2007.tar
# backup/         LICENSE.fuck    python/          VOCtrainval_11-May-2012.tar
# cfg/            LICENSE.gen     README.md        yolov3-tiny.weights
# darknet*        LICENSE.gpl     results/         yolov3.weights
# data/           LICENSE.meta    scripts/

# %%
# !cat 2007_train.txt 2007_val.txt 2012_*.txt > train.txt

# %%
ls
# Out:
# 2007_test.txt   examples/       LICENSE.mit      src/
# 2007_train.txt  include/        LICENSE.v1       train.txt
# 2007_val.txt    libdarknet.a    Makefile         VOCdevkit/
# 2012_train.txt  libdarknet.so*  obj/             voc_label.py
# 2012_val.txt    LICENSE         predictions.jpg  VOCtest_06-Nov-2007.tar
# backup/         LICENSE.fuck    python/          VOCtrainval_06-Nov-2007.tar
# cfg/            LICENSE.gen     README.md        VOCtrainval_11-May-2012.tar
# darknet*        LICENSE.gpl     results/         yolov3-tiny.weights
# data/           LICENSE.meta    scripts/         yolov3.weights

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-08-04 07:18:43--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  97.3MB/s    in 1.6s
#
# 2021-08-04 07:18:45 (97.3 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
#!./darknet detector train cfg/voc.data cfg/yolov3-tiny-voc.cfg darknet53.conv.74 | tee training.log
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32  0.299 BFLOPs
#     1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64  1.595 BFLOPs
#     2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32  0.177 BFLOPs
#     3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64  1.595 BFLOPs
#     4 res    1                 208 x 208 x  64   ->   208 x 208 x  64
#     5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128  1.595 BFLOPs
#     6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64  0.177 BFLOPs
#     7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128  1.595 BFLOPs
#     8 res    5                 104 x 104 x 128   ->   104 x 104 x 128
#     9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64  0.177 BFLOPs
#    10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128  1.595 BFLOPs
# ...

# %%
# !./darknet detector train cfg/voc.data cfg/yolov3-tiny-voc.cfg darknet53.conv.74 | tee training.log
# Out:
# Streaming output truncated to the last 5000 lines.
# Region 23 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000241, .5R: -nan, .75R: -nan,  count: 0
# Region 16 Avg IOU: 0.837583, Class: 0.998843, Obj: 0.139604, No Obj: 0.000860, .5R: 1.000000, .75R: 1.000000,  count: 1
# Region 23 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000126, .5R: -nan, .75R: -nan,  count: 0
# Region 16 Avg IOU: 0.684671, Class: 0.997858, Obj: 0.161917, No Obj: 0.003585, .5R: 0.800000, .75R: 0.400000,  count: 5
# Region 23 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000197, .5R: -nan, .75R: -nan,  count: 0
# Region 16 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000262, .5R: -nan, .75R: -nan,  count: 0
# Region 23 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000029, .5R: -nan, .75R: -nan,  count: 0
# Region 16 Avg IOU: 0.707046, Class: 0.998926, Obj: 0.693621, No Obj: 0.003509, .5R: 1.000000, .75R: 0.500000,  count: 4
# ...

# %%
ls

# %%
# !python extract_log.py

# %%
# !python visualization_loss.py
# Out:
# [479.349609 442.020416 549.493713 505.18219  324.366302 425.025818
#  460.316467 400.571594 578.055725 439.708527 390.385406 406.394287
#  286.584656 270.610687 263.648438 318.88855  400.101044 326.218567
#  492.668823 424.891296 443.965759 367.653076 220.570892 213.204529
#  138.577591 147.775528 141.997894 185.120651 164.66478  148.527451
#   96.2883    81.152939  58.111462  71.547089  59.881241  47.323334
#   29.020807  17.467451  20.423033  15.455505  14.488767  11.088121
#    9.005449   6.197661   9.801468   5.329701   6.094391   4.671971
#    3.92848    3.491231   3.410082   3.82856    4.575534   3.651798
#    2.547053   2.616501   3.067521   4.048257   3.407489   3.321847
#    2.965719   4.060889   5.650291   4.686945   3.434355   3.290907
#    3.328522   3.585907   3.757149   2.662134   2.751097   3.539631
#    3.41146    3.369102   2.332587   2.629404   3.440323   3.023631
#    3.317313   3.030509   3.859785   2.722211   2.614743   2.614214
# ...

# %%
# !python get_ground_truth\(annotation2Ground_Truth.npy\).py
# Out:
# Traceback (most recent call last):
#   File "get_ground_truth(annotation2Ground_Truth.npy).py", line 47, in <module>
#     solve()
#   File "get_ground_truth(annotation2Ground_Truth.npy).py", line 21, in solve
#     annotation_files = os.listdir(annotations_path)
# FileNotFoundError: [Errno 2] No such file or directory: './INRIAPerson/Test/annotations/'

# %%
# !./darknet detect cfg/yolov3-tiny.cfg yolov3.weights data/dog.jpg
# Out:
# layer     filters    size              input                output
#     0 conv     16  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  16  0.150 BFLOPs
#     1 max          2 x 2 / 2   416 x 416 x  16   ->   208 x 208 x  16
#     2 conv     32  3 x 3 / 1   208 x 208 x  16   ->   208 x 208 x  32  0.399 BFLOPs
#     3 max          2 x 2 / 2   208 x 208 x  32   ->   104 x 104 x  32
#     4 conv     64  3 x 3 / 1   104 x 104 x  32   ->   104 x 104 x  64  0.399 BFLOPs
#     5 max          2 x 2 / 2   104 x 104 x  64   ->    52 x  52 x  64
#     6 conv    128  3 x 3 / 1    52 x  52 x  64   ->    52 x  52 x 128  0.399 BFLOPs
#     7 max          2 x 2 / 2    52 x  52 x 128   ->    26 x  26 x 128
#     8 conv    256  3 x 3 / 1    26 x  26 x 128   ->    26 x  26 x 256  0.399 BFLOPs
#     9 max          2 x 2 / 2    26 x  26 x 256   ->    13 x  13 x 256
#    10 conv    512  3 x 3 / 1    13 x  13 x 256   ->    13 x  13 x 512  0.399 BFLOPs
# ...

# %%
# !./darknet detect cfg/yolov3-tiny.cfg yolov3.weights data/person.jpg
# Out:
# layer     filters    size              input                output
#     0 conv     16  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  16  0.150 BFLOPs
#     1 max          2 x 2 / 2   416 x 416 x  16   ->   208 x 208 x  16
#     2 conv     32  3 x 3 / 1   208 x 208 x  16   ->   208 x 208 x  32  0.399 BFLOPs
#     3 max          2 x 2 / 2   208 x 208 x  32   ->   104 x 104 x  32
#     4 conv     64  3 x 3 / 1   104 x 104 x  32   ->   104 x 104 x  64  0.399 BFLOPs
#     5 max          2 x 2 / 2   104 x 104 x  64   ->    52 x  52 x  64
#     6 conv    128  3 x 3 / 1    52 x  52 x  64   ->    52 x  52 x 128  0.399 BFLOPs
#     7 max          2 x 2 / 2    52 x  52 x 128   ->    26 x  26 x 128
#     8 conv    256  3 x 3 / 1    26 x  26 x 128   ->    26 x  26 x 256  0.399 BFLOPs
#     9 max          2 x 2 / 2    26 x  26 x 256   ->    13 x  13 x 256
#    10 conv    512  3 x 3 / 1    13 x  13 x 256   ->    13 x  13 x 512  0.399 BFLOPs
# ...

# %%
# !./darknet detect cfg/yolov3-tiny.cfg backup/yolov3-tiny_900.weights data/person.jpg
# Out:
# layer     filters    size              input                output
#     0 conv     16  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  16  0.150 BFLOPs
#     1 max          2 x 2 / 2   416 x 416 x  16   ->   208 x 208 x  16
#     2 conv     32  3 x 3 / 1   208 x 208 x  16   ->   208 x 208 x  32  0.399 BFLOPs
#     3 max          2 x 2 / 2   208 x 208 x  32   ->   104 x 104 x  32
#     4 conv     64  3 x 3 / 1   104 x 104 x  32   ->   104 x 104 x  64  0.399 BFLOPs
#     5 max          2 x 2 / 2   104 x 104 x  64   ->    52 x  52 x  64
#     6 conv    128  3 x 3 / 1    52 x  52 x  64   ->    52 x  52 x 128  0.399 BFLOPs
#     7 max          2 x 2 / 2    52 x  52 x 128   ->    26 x  26 x 128
#     8 conv    256  3 x 3 / 1    26 x  26 x 128   ->    26 x  26 x 256  0.399 BFLOPs
#     9 max          2 x 2 / 2    26 x  26 x 256   ->    13 x  13 x 256
#    10 conv    512  3 x 3 / 1    13 x  13 x 256   ->    13 x  13 x 512  0.399 BFLOPs
# ...

# %%
# !./darknet detect cfg/yolov3-tiny.cfg backup/yolov3-tiny_900.weights VOCdevkit/VOC2007/JPEGImages/000447.jpg
# Out:
# layer     filters    size              input                output
#     0 conv     16  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  16  0.150 BFLOPs
#     1 max          2 x 2 / 2   416 x 416 x  16   ->   208 x 208 x  16
#     2 conv     32  3 x 3 / 1   208 x 208 x  16   ->   208 x 208 x  32  0.399 BFLOPs
#     3 max          2 x 2 / 2   208 x 208 x  32   ->   104 x 104 x  32
#     4 conv     64  3 x 3 / 1   104 x 104 x  32   ->   104 x 104 x  64  0.399 BFLOPs
#     5 max          2 x 2 / 2   104 x 104 x  64   ->    52 x  52 x  64
#     6 conv    128  3 x 3 / 1    52 x  52 x  64   ->    52 x  52 x 128  0.399 BFLOPs
#     7 max          2 x 2 / 2    52 x  52 x 128   ->    26 x  26 x 128
#     8 conv    256  3 x 3 / 1    26 x  26 x 128   ->    26 x  26 x 256  0.399 BFLOPs
#     9 max          2 x 2 / 2    26 x  26 x 256   ->    13 x  13 x 256
#    10 conv    512  3 x 3 / 1    13 x  13 x 256   ->    13 x  13 x 512  0.399 BFLOPs
# ...
